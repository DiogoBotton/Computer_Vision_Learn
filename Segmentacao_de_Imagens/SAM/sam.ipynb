# %% [markdown]
# Rodar os comandos abaixo manualmente, caso der erro, inclusive, baixar o arquivo manualmente caso for windows.

# %%
# !pip install opencv-python matplotlib
# !pip install 'git+https://github.com/facebookresearch/segment-anything.git'
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: "'git+https://github.com/facebookresearch/segment-anything.git'": Expected package name at the start of dependency specifier
#     'git+https://github.com/facebookresearch/segment-anything.git'
#     ^

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import cv2
import sys
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

# %%
image = cv2.imread('knee01.png') 
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
sam_checkpoint = "sam_vit_h_4b8939.pth"
model_type = "vit_h"
device = "cuda"
sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
sam.to(device=device)

# Existem diversas configurações para o uso da biblioteca! 
mask_generator_ = SamAutomaticMaskGenerator(
    model=sam,
    points_per_side=32,
    pred_iou_thresh=0.9,
    stability_score_thresh=0.96,
    crop_n_layers=1,
    crop_n_points_downscale_factor=2,
    min_mask_region_area=100,  # Requires open-cv to run post-processing
)

masks = mask_generator_.generate(image)
print(len(masks))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 18
#       5 #sam.to(device=device)
#       6
#       7 # Existem diversas configurações para o uso da biblioteca!
#       8 mask_generator_ = SamAutomaticMaskGenerator(
#       9     model=sam,
#      10     points_per_side=32,
#    (...)
#      15     min_mask_region_area=100,  # Requires open-cv to run post-processing
#      16 )
# ---> 18 masks = mask_generator_.generate(image)
#      19 print(len(masks))
#
# File c:\Users\DIOGO-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# ...

# %%
# Plotando tudo o que foi encontrado
def show_anns(anns):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)
    polygons = []
    color = []
    for ann in sorted_anns:
        m = ann['segmentation']
        img = np.ones((m.shape[0], m.shape[1], 3))
        color_mask = np.random.random((1, 3)).tolist()[0]
        for i in range(3):
            img[:,:,i] = color_mask[i]
        ax.imshow(np.dstack((img, m*0.35)))

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
show_anns(masks)
plt.axis('off')
plt.show()
